# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
images = '../datasets/lego/train/'

# %%
i=0
name=os.listdir(images)[i]
img = cv2.imread(images+name)

plt.imshow(img[...,[2,1,0]])
# Out:
# r_0_png

# %%
s=img.shape
x=np.random.randint(s[0]/10, s[0]/4)
y=np.random.randint(s[0]/10, s[1]/4)
x_off=np.random.randint(0, s[0]-x)
y_off=np.random.randint(0, s[1]-y)

c=np.random.randint(0,255,3)

img[x_off:x_off+x,y_off:y_off+y]=c

print(c)

plt.imshow(img[...,[2,1,0]])
# Out:
# [168 136  65]

# %%
for image in os.listdir(images):
    
    img0 = cv2.imread(images+image)
    img1 = cv2.imread(images+image)

    s=img0.shape
    x=np.random.randint(s[0]/10, s[0]/4)
    y=np.random.randint(s[0]/10, s[1]/4)
    x_off=np.random.randint(0, s[0]-x)
    y_off=np.random.randint(0, s[1]-y)
    c=np.random.randint(0,255,3)
    img0[x_off:x_off+x,y_off:y_off+y]=c

    x=np.random.randint(s[0]/10, s[0]/4)
    y=np.random.randint(s[0]/10, s[1]/4)
    x_off=np.random.randint(0, s[0]-x)
    y_off=np.random.randint(0, s[1]-y)
    c=np.random.randint(0,255,3)
    img1[x_off:x_off+x,y_off:y_off+y]=c

    path = image.split('.')[0] + '_.' + image.split('.')[1]
    cv2.imwrite(images+image, img0)
    cv2.imwrite(images+path, img1)
    print(image)
# Out:
# r_0.png
# r_1.png
# r_10.png
# r_11.png
# r_12.png
# r_13.png
# r_14.png
# r_15.png
# r_16.png
# r_17.png
# r_18.png
# r_19.png
# r_2.png
# r_20.png
# r_21.png
# r_22.png
# r_23.png
# r_24.png
# r_25.png
# r_26.png
# r_27.png
# r_28.png
# r_29.png
# r_3.png
# r_30.png
# r_31.png
# r_32.png
# r_33.png
# r_34.png
# r_35.png
# r_36.png
# r_37.png
# r_38.png
# r_39.png
# r_4.png
# r_40.png
# r_41.png
# r_42.png
# r_43.png
# r_44.png
# r_45.png
# r_46.png
# r_47.png
# r_48.png
# r_49.png
# r_5.png
# r_50.png
# r_51.png
# r_52.png
# r_53.png
# r_54.png
# r_55.png
# r_56.png
# r_57.png
# r_58.png
# r_59.png
# r_6.png
# r_60.png
# r_61.png
# r_62.png
# r_63.png
# r_64.png
# r_65.png
# r_66.png
# r_67.png
# r_68.png
# r_69.png
# r_7.png
# r_70.png
# r_71.png
# r_72.png
# r_73.png
# r_74.png
# r_75.png
# r_76.png
# r_77.png
# r_78.png
# r_79.png
# r_8.png
# r_80.png
# r_81.png
# r_82.png
# r_83.png
# r_84.png
# r_85.png
# r_86.png
# r_87.png
# r_88.png
# r_89.png
# r_9.png
# r_90.png
# ...
