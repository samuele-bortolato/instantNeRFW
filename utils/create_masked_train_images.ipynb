# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
images = 'datasets/greendino/images_0/'
depth = 'C:/Users/Sam/Downloads/greendino/greendino/1_leresdepthmaps/'
targets = 'datasets/greendino/images/'

# %%
i=0
name=os.listdir(images)[i]
img = cv2.imread(images+name)
dpt = cv2.imread(depth+name.replace('.jpg','.png'), cv2.IMREAD_GRAYSCALE)

# %%
dpt.min(), dpt.max()
# Out:
# (0, 255)

# %%
dpt.shape
# Out:
# (1264, 1264)

# %%
T, _ = cv2.threshold(dpt, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)
print(T)
plt.figure(figsize=(15,10))
plt.subplot(1,2,1)
plt.imshow(dpt)
plt.subplot(1,2,2)
plt.imshow(dpt<T+25)
# Out:
# 111.0

# %%
mask=(dpt<(T+25))
mask.shape
# Out:
# (1264, 1264)

# %%
kernel=np.ones((21,21))
d=cv2.dilate(mask*1., kernel, iterations=1).astype(int)
plt.imshow(d)
d.shape
# Out:
# (1264, 1264)

# %%
plt.figure(figsize=(15,10))
plt.subplot(1,2,1)
plt.imshow(img)
plt.subplot(1,2,2)
plt.imshow(img*d[:-1,:-1,None])

# %%
C=50
kernel=np.ones((21,21))

for image in os.listdir(images):
    
    img = cv2.imread(images+image)
    dpt = cv2.imread(depth+image.replace('.jpg','.png'), cv2.IMREAD_GRAYSCALE)

    T, _ = cv2.threshold(dpt, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)

    mask=(dpt<(T+C))
    mask=cv2.dilate(mask*1., kernel, iterations=1).astype(int)

    img = img * mask[:-1,:-1,None]
    cv2.imwrite(targets+image, img)
    print(image)
# Out:
# 0.jpg
# 1.jpg
# 10.jpg
# 116.jpg
# 117.jpg
# 118.jpg
# 123.jpg
# 124.jpg
# 125.jpg
# 126.jpg
# 127.jpg
# 128.jpg
# 129.jpg
# 13.jpg
# 130.jpg
# 131.jpg
# 132.jpg
# 133.jpg
# 134.jpg
# 137.jpg
# 138.jpg
# 139.jpg
# 140.jpg
# 141.jpg
# 142.jpg
# 143.jpg
# 144.jpg
# 146.jpg
# 148.jpg
# 149.jpg
# 150.jpg
# 151.jpg
# 152.jpg
# 177.jpg
# 178.jpg
# 179.jpg
# 180.jpg
# 181.jpg
# 182.jpg
# 183.jpg
# 184.jpg
# 193.jpg
# 195.jpg
# 196.jpg
# 197.jpg
# 199.jpg
# 2.jpg
# 200.jpg
# 201.jpg
# 202.jpg
# 203.jpg
# 204.jpg
# 205.jpg
# 206.jpg
# 207.jpg
# 208.jpg
# 209.jpg
# 210.jpg
# 212.jpg
# 213.jpg
# 214.jpg
# 216.jpg
# 217.jpg
# 218.jpg
# 219.jpg
# 220.jpg
# 221.jpg
# 222.jpg
# 240.jpg
# 241.jpg
# 242.jpg
# 243.jpg
# 244.jpg
# 245.jpg
# 246.jpg
# 247.jpg
# 248.jpg
# 249.jpg
# 250.jpg
# 251.jpg
# 256.jpg
# 258.jpg
# 259.jpg
# 260.jpg
# 261.jpg
# 262.jpg
# 263.jpg
# 264.jpg
# 265.jpg
# 266.jpg
# 267.jpg
# 268.jpg
# 269.jpg
# 270.jpg
# 3.jpg
# 39.jpg
# 40.jpg
# 41.jpg
# 42.jpg
# 43.jpg
# 44.jpg
# 45.jpg
# 46.jpg
# 47.jpg
# 48.jpg
# 49.jpg
# 5.jpg
# 52.jpg
# 53.jpg
# 55.jpg
# 58.jpg
# 59.jpg
# 6.jpg
# 60.jpg
# 61.jpg
# 62.jpg
# 63.jpg
# 64.jpg
# 65.jpg
# 66.jpg
# 67.jpg
# 68.jpg
# 69.jpg
# 7.jpg
# 71.jpg
# 74.jpg
# 75.jpg
# 76.jpg
# 77.jpg
# 78.jpg
# 79.jpg
# 8.jpg
# 80.jpg
# 81.jpg
# 82.jpg
# 83.jpg
# 84.jpg
# 86.jpg
# 87.jpg
# 88.jpg
# 89.jpg
# 9.jpg
# 90.jpg
# 91.jpg
# 94.jpg
# 95.jpg
# 97.jpg
# 98.jpg
# 99.jpg
